# %% [markdown]
# # Evaluation demo
# This notebook reproduces the evaluation framework of the Formula 1 Retrieval-Augmented Generation (RAG) chatbot.

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

from evaluation import (
    evaluate_retrieval_metrics,
    evaluate_generation_metrics,
    evaluate_latency,
    evaluate_sources_and_citations
)

# %% [markdown]
# Retrieval metrics

# %%
retrieval_results = evaluate_retrieval_metrics(top_k=5)

retrieval_df = pd.DataFrame(retrieval_results)

retrieval_df
# Out:
# 2026-06-12 00:00:38,431 [INFO] Loading embedding model 'multi-qa-MiniLM-L6-cos-v1' …
# 2026-06-12 00:00:38,454 [INFO] No device provided, using mps
# 2026-06-12 00:00:38,626 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/multi-qa-MiniLM-L6-cos-v1/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 2026-06-12 00:00:38,627 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-06-12 00:00:38,637 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/multi-qa-MiniLM-L6-cos-v1/b207367332321f8e44f96e224ef15bc607f4dbf0/modules.json "HTTP/1.1 200 OK"
# 2026-06-12 00:00:38,765 [INFO] HTTP Request: HEAD https://huggingface.co/sentence-transformers/multi-qa-MiniLM-L6-cos-v1/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# ...

# %%
print(
    f"Average Precision@5: "
    f"{retrieval_df['precision@5'].mean():.3f}"
)

print(
    f"Average Recall@5: "
    f"{retrieval_df['recall@5'].mean():.3f}"
)

print(
    f"Average MRR: "
    f"{retrieval_df['mrr'].mean():.3f}"
)
# Out:
# Average Precision@5: 0.880
# Average Recall@5: 1.000
# Average MRR: 1.000

# %% [markdown]
# Generation metrics

# %%
generation_results = evaluate_generation_metrics(top_k=5)

generation_df = pd.DataFrame(generation_results)

generation_df
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:00:48,140 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:00:58,621 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:03,312 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:08,120 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:12,096 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#                                             question  \
# 0  How many Formula One World Drivers' Championsh...
# ...

# %% [markdown]
# Latency evaluation

# %%
latency_results = evaluate_latency(top_k=5)

latency_df = pd.DataFrame(latency_results)

latency_df
# Out:
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:14,265 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:19,516 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:22,173 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:24,251 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:26,219 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
#                                             question  \
# 0  How many Formula One World Drivers' Championsh...
# 1  What is the Circuit de Monaco and what major r...
# ...

# %%
print(
    f"Average Retrieval Latency: "
    f"{latency_df['retrieval_latency_seconds'].mean():.3f} seconds"
)

print(
    f"Average Generation Latency: "
    f"{latency_df['generation_latency_seconds'].mean():.3f} seconds"
)
# Out:
# Average Retrieval Latency: 0.082 seconds
# Average Generation Latency: 2.708 seconds

# %% [markdown]
# Sources evaluation

# %%
citation_results = evaluate_sources_and_citations(top_k=5)

citation_df = pd.DataFrame(citation_results)

citation_df
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:28,169 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:35,699 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:38,899 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:40,975 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-06-12 00:01:43,438 [INFO] HTTP Request: POST http://localhost:11434/v1/chat/completions "HTTP/1.1 200 OK"
#                                             question  \
# 0  How many Formula One World Drivers' Championsh...
# 1  What is the Circuit de Monaco and what major r...
# ...

# %%
print(
    f"Percentage of answers containing citations: "
    f"{citation_df['has_sources'].mean()*100:.1f}%"
)

print(
    f"Percentage of answers containing expected citations: "
    f"{citation_df['contains_expected_source'].mean()*100:.1f}%"
)
# Out:
# Percentage of answers containing citations: 100.0%
# Percentage of answers containing expected citations: 100.0%
